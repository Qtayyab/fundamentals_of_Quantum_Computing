# %%
# !pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 46.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 12.2 MB/s eta 0:00:00
# ...

# %%
# !pip install qiskit_aer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 28.8 MB/s eta 0:00:00
# ...

# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, array_to_latex, plot_bloch_multivector
# %matplotlib inline

# %%
# !pip install pylatexenc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136818 sha256=0c66a44d9f3963a9bf0daa6734731b1400169720f3b0b153f7d362da433136a6
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %% [markdown]
# # Correlated Bell States

# %%
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)
circuit.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector, prefix="\\text{statevector = } \n")
# Out:
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = simulator).result()
plot_histogram(result.get_counts())

# %% [markdown]
# Thus, everytime it is giving both zero or both 1. Thus, these two qubits are perfectly correlated

# %% [markdown]
# # Anti-correlated Bell States

# %%
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)
circuit.cx(0, 1)
circuit.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector, prefix="\\text{statevector = } \n")
# Out:
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# 0 & \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = simulator).result()
plot_histogram(result.get_counts())

# %% [markdown]
# # Challenge

# %% [markdown]
# Build an entanglement state GHZ which is actually an entangled state of three correlated qubits

# %%
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.cnot(0, 1)
circuit.cnot(1, 2)
circuit.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector, prefix="\\text{statevector = } \n")
# Out:
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & 0 & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = simulator).result()
plot_histogram(result.get_counts())

# %% [markdown]
# Here we put the control qubit to second qubit, but it doesn't matter, if we make control qubit to first qubit. As, they are both entangled now.

# %%
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.cnot(0, 1)
circuit.cnot(0, 2)
circuit.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector, prefix="\\text{statevector = } \n")
# Out:
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & 0 & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = simulator).result()
plot_histogram(result.get_counts())

# %% [markdown]
# # Challenge 2

# %%
import qiskit

circuit = qiskit.QuantumCircuit(3)

# Add a Hadamard gate to qubit 2.
circuit.h(2)

# Add a CNOT gate between qubits 1 and 2.
circuit.cx(1, 2)

# Add a CNOT gate between qubits 0 and 2.
circuit.cx(0, 2)

# Draw the circuit.
circuit.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector, prefix="\\text{statevector = } \n")
# Out:
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend = simulator).result()
plot_histogram(result.get_counts())

# %% [markdown]
# THE END
